# %%
# Versão do Python
from platform import python_version
print('Versão do python Usada:', python_version())
# Out:
# Versão do python Usada: 3.9.20

# %%
# %env TF_CPP_MIN_LOG_LEVEL=3
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
# Imports para manipulação e visualização de dados
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# Imports para manipulação de imagens
import os
import cv2
import itertools
import shutil
import imageio
import skimage
import skimage.io
import skimage.transform
from pathlib import Path

# Imports para Deep Learning
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.metrics import binary_accuracy

# Imports para cálculo de métricas e outras tarefas
import sklearn
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Supress de warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark --iversions
# Out:
# sklearn   : 1.5.2
# platform  : 1.0.8
# skimage   : 0.24.0
# keras     : 3.6.0
# matplotlib: 3.9.2
# numpy     : 2.0.2
# pandas    : 2.2.3
# imageio   : 2.36.0
# tensorflow: 2.18.0
# cv2       : 4.10.0

# %%
import tensorflow as tf

print("GPUs disponíveis:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs disponíveis: []

# %% [markdown]
# ## Coletando e Compreendendo os Dados de Imagens de Pulmões Saudáveis e Doentes
#
# **Conjunto de raios-X do Condado de Montgomery**: As imagens de raios-X deste conjunto de dados foram adquiridas no programa de controle da tuberculose do Departamento de Saúde e Serviços Humanos do Condado de Montgomery, MD, EUA. Este conjunto contém 138 radiografias póstero-anteriores, das quais 80 radiografias são normais e 58 radiografias são anormais com manifestações de tuberculose. Todas as imagens são anônimas e estão disponíveis no formato PNG. O conjunto de dados inclui leituras de radiologia disponíveis como arquivo de texto.
#
# **Conjunto de raios X do Hospital de Shenzhen**: As imagens de raios X deste conjunto de dados foram coletadas pelo Hospital de Shenzhen em Shenzhen, providência em Guangdong, China. Os raios X foram adquiridos como parte dos cuidados de rotina no Hospital de Shenzhen. O conjunto contém imagens no formato PNG. Existem 326 radiografias normais e 336 radiografias anormais, mostrando várias manifestações de tuberculose.
#
# Fonte de Dados:
#
# https://lhncbc.nlm.nih.gov/LHC-downloads/downloads.html#tuberculosis-image-data-sets

# %% [markdown]
# ## Definindo o Local de Armazenamento das Imagens

# %%
# Diretórios para os 2 grupos de imagens
imagens_shen = 'dados/ChinaSet_AllFiles/CXR_png/'
imagens_mont = 'dados/MontgomerySet/CXR_png/'

# %%
# Print do tamanho de cada pasta
print(len(os.listdir(imagens_shen)))
print(len(os.listdir(imagens_mont)))
# Out:
# 663
# 139

# %%
# Grava a lista de imagens em cada pasta
shen_image_list = os.listdir(imagens_shen)
mont_image_list = os.listdir(imagens_mont)

# %% [markdown]
# ## Preparando e Carregando as Imagens de Raio-X

# %%
df_shen = pd.DataFrame(shen_image_list, columns = ['image_id'])
df_mont = pd.DataFrame(mont_image_list, columns = ['image_id'])

# %%
# Remove da lista o nome 'Thumbs.db'
df_shen = df_shen[df_shen['image_id'] != 'Thumbs.db']
df_mont = df_mont[df_mont['image_id'] != 'Thumbs.db']

# %%
# Reset do índice
df_shen.reset_index(inplace = True, drop = True)
df_mont.reset_index(inplace = True, drop = True)

# %%
# Print do Shape
print(df_shen.shape)
# Out:
# (662, 1)

# %%
# Print do Shape
print(df_mont.shape)
# Out:
# (138, 1)

# %%
# Visualiza os dados
df_shen.head()
# Out:
#             image_id
# 0  CHNCXR_0001_0.png
# 1  CHNCXR_0002_0.png
# 2  CHNCXR_0003_0.png
# 3  CHNCXR_0004_0.png
# 4  CHNCXR_0005_0.png

# %%
# Visualiza os dados
df_mont.head()
# Out:
#             image_id
# 0  MCUCXR_0001_0.png
# 1  MCUCXR_0002_0.png
# 2  MCUCXR_0003_0.png
# 3  MCUCXR_0004_0.png
# 4  MCUCXR_0005_0.png

# %% [markdown]
# ## Extraindo a Variável Target

# %%
# Extração da Variável Target

def extrair_target(x):
    
    target = int(x[-5])
    
    if target == 0:
        return 'Normal'
    if target == 1:
        return 'Tuberculose'

# %%
# Adicionando label aos dataframe
df_shen['target'] = df_shen['image_id'].apply(extrair_target)
df_mont['target'] = df_mont['image_id'].apply(extrair_target)

# %%
# Visualiza os dados
df_shen.head()
# Out:
#             image_id  target
# 0  CHNCXR_0001_0.png  Normal
# 1  CHNCXR_0002_0.png  Normal
# 2  CHNCXR_0003_0.png  Normal
# 3  CHNCXR_0004_0.png  Normal
# 4  CHNCXR_0005_0.png  Normal

# %%
# Visualiza os dados
df_mont.head()
# Out:
#             image_id  target
# 0  MCUCXR_0001_0.png  Normal
# 1  MCUCXR_0002_0.png  Normal
# 2  MCUCXR_0003_0.png  Normal
# 3  MCUCXR_0004_0.png  Normal
# 4  MCUCXR_0005_0.png  Normal

# %%
# Shenzen Dataset
df_shen['target'].value_counts()
# Out:
# target
# Tuberculose    336
# Normal         326
# Name: count, dtype: int64

# %%
# Montgomery Dataset
df_mont['target'].value_counts()
# Out:
# target
# Normal         80
# Tuberculose    58
# Name: count, dtype: int64

# %% [markdown]
# ## Visualizando as Imagens

# %%
# Função para visualizar as imagens
def visualiza_images(col_name, figure_cols, df, caminho_imagens):

    categories = (df.groupby([col_name])[col_name].nunique()).index
    
    f, ax = plt.subplots(nrows = len(categories), 
                         ncols = figure_cols, 
                         figsize = (4 * figure_cols, 4 * len(categories))) 
    
    for i, cat in enumerate(categories):
        
        sample = df[df[col_name] == cat].sample(figure_cols) 
        
        for j in range(0, figure_cols):
            
            file = caminho_imagens + sample.iloc[j]['image_id']
            
            # Lê a imagem do disco
            im = imageio.imread(file)
            
            ax[i, j].imshow(im, resample = True, cmap = 'gray')
            ax[i, j].set_title(cat, fontsize = 14)  
            
    plt.tight_layout()
    plt.show()

# %%
# Shenzen Dataset
visualiza_images('target', 4, df_shen, imagens_shen)

# %%
# Montgomery Dataset
visualiza_images('target', 4, df_mont, imagens_mont)

# %% [markdown]
# ## Ajustando e Organizando o Dataset Shenzen de Imagens de Raio-X

# %%
caminho_imagens = imagens_shen

# %%
# Função para leitura dos metadados das imagens
def leitura_imagens(file_name):

    image = cv2.imread(caminho_imagens + file_name)
    
    max_pixel_val = image.max()
    min_pixel_val = image.min()
    
    # image.shape[0] - largura da imagem 
    # image.shape[1] - altura da imagem 
    # image.shape[2] - número de canais
    # Se o shape não tiver um valor para num_channels (altura, largura) então atribuímos 1 ao número de canais.
    if len(image.shape) > 2: 
        output = [image.shape[0], image.shape[1], image.shape[2], max_pixel_val, min_pixel_val]
    else:
        output = [image.shape[0], image.shape[1], 1, max_pixel_val, min_pixel_val]
    return output

# %%
meta_shen = np.stack(df_shen['image_id'].apply(leitura_imagens))

# %%
df = pd.DataFrame(meta_shen, columns = ['largura', 'altura', 'canais', 'maior_valor_pixel', 'menor_valor_pixel'])

# %%
df_shen = pd.concat([df_shen, df], axis = 1, sort = False)

# %%
df_shen.shape
# Out:
# (662, 7)

# %%
df_shen.head()
# Out:
#             image_id  target  largura  altura  canais  maior_valor_pixel  \
# 0  CHNCXR_0001_0.png  Normal     2919    3000       3                255
# 1  CHNCXR_0002_0.png  Normal     2951    3000       3                255
# 2  CHNCXR_0003_0.png  Normal     2945    2987       3                255
# 3  CHNCXR_0004_0.png  Normal     2933    3000       3                255
# 4  CHNCXR_0005_0.png  Normal     2933    3000       3                255
#
#    menor_valor_pixel
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
# Não precisamos mais desse dataframe. Removemos para liberar espaço na memória RAM.
del df

# %% [markdown]
# ## Ajustando e Organizando o Dataset Montgomery de Imagens de Raio-X

# %%
caminho_imagens = imagens_mont

# %%
meta_mont = np.stack(df_mont['image_id'].apply(leitura_imagens))

# %%
df = pd.DataFrame(meta_mont, columns = ['largura', 'altura', 'canais', 'maior_valor_pixel', 'menor_valor_pixel'])

# %%
df_mont = pd.concat([df_mont, df], axis = 1, sort = False)

# %%
df_mont.head()
# Out:
#             image_id  target  largura  altura  canais  maior_valor_pixel  \
# 0  MCUCXR_0001_0.png  Normal     4020    4892       3                255
# 1  MCUCXR_0002_0.png  Normal     4020    4892       3                255
# 2  MCUCXR_0003_0.png  Normal     4892    4020       3                255
# 3  MCUCXR_0004_0.png  Normal     4892    4020       3                255
# 4  MCUCXR_0005_0.png  Normal     4892    4020       3                255
#
#    menor_valor_pixel
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
# Não precisamos mais desse dataframe. Removemos para liberar espaço na memória RAM.
del df

# %% [markdown]
# ## Divisão dos Dados em Treino e Validação
#
# Tarefas que serão realizadas para o treinamento do modelo:
#
# - 1. Concatenar os datasets de imagens
# - 2. "Embaralhar" (shuffle) as imagens
# - 3. Separar as imagens por classes (Normal / Tuberculose)
# - 4. Dividir os dados em treino e validação/teste
# - 5. Aplicar as técnicas de processamento de imagens (como redimensionamento) em treino e validação/teste de forma separada

# %%
df_shen['target'].value_counts()
# Out:
# target
# Tuberculose    336
# Normal         326
# Name: count, dtype: int64

# %%
df_mont['target'].value_counts()
# Out:
# target
# Normal         80
# Tuberculose    58
# Name: count, dtype: int64

# %%
df_data = pd.concat([df_shen, df_mont], axis = 0).reset_index(drop = True)

# %%
df_data = shuffle(df_data)

# %%
df_data.shape
# Out:
# (800, 7)

# %%
df_data.head()
# Out:
#               image_id       target  largura  altura  canais  \
# 453  CHNCXR_0454_1.png  Tuberculose     2896    2599       3
# 211  CHNCXR_0212_0.png       Normal     2585    2792       3
# 79   CHNCXR_0080_0.png       Normal     2955    3000       3
# 432  CHNCXR_0433_1.png  Tuberculose     2942    3001       3
# 131  CHNCXR_0132_0.png       Normal     2943    2997       3
#
#      maior_valor_pixel  menor_valor_pixel
# 453                255                  0
# 211                255                  0
# 79                 255                  0
# 432                255                  0
# 131                255                  0

# %%
df_data['labels'] = df_data['target'].map({'Normal':0, 'Tuberculose':1})

# %%
df_data.head()
# Out:
#               image_id       target  largura  altura  canais  \
# 453  CHNCXR_0454_1.png  Tuberculose     2896    2599       3
# 211  CHNCXR_0212_0.png       Normal     2585    2792       3
# 79   CHNCXR_0080_0.png       Normal     2955    3000       3
# 432  CHNCXR_0433_1.png  Tuberculose     2942    3001       3
# 131  CHNCXR_0132_0.png       Normal     2943    2997       3
#
#      maior_valor_pixel  menor_valor_pixel  labels
# 453                255                  0       1
# 211                255                  0       0
# 79                 255                  0       0
# 432                255                  0       1
# 131                255                  0       0

# %%
y = df_data['labels']

# %%
df_treino, df_val = train_test_split(df_data, test_size = 0.15, random_state = 101, stratify = y)

# %%
print(df_treino.shape)
print(df_val.shape)
# Out:
# (680, 8)
# (120, 8)

# %%
# Total de registros
df_treino['target'].value_counts()
# Out:
# target
# Normal         345
# Tuberculose    335
# Name: count, dtype: int64

# %%
# Total de registros
df_val['target'].value_counts()
# Out:
# target
# Normal         61
# Tuberculose    59
# Name: count, dtype: int64

# %% [markdown]
# ## Separando as Imagens Organizadas Por Classe

# %%
base_dir = 'dados_final/'

dir_base = Path(base_dir)

if dir_base.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(base_dir)

# %%
dados_treino = os.path.join(base_dir, 'dados_treino/')

dir_treino = Path(dados_treino)

if dir_treino.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(dados_treino)

# %%
dados_val = os.path.join(base_dir, 'dados_val/')

dir_val = Path(dados_val)

if dir_val.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(dados_val)

# %%
Normal = os.path.join(dados_treino, 'Normal')

dir_normal_treino = Path(Normal)

if dir_normal_treino.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(Normal)

# %%
Tuberculose = os.path.join(dados_treino, 'Tuberculose')

dir_tb_treino = Path(Tuberculose)

if dir_tb_treino.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(Tuberculose)

# %%
Normal = os.path.join(dados_val, 'Normal')

dir_normal_val = Path(Normal)

if dir_normal_val.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(Normal)

# %%
Tuberculose = os.path.join(dados_val, 'Tuberculose')

dir_tb_val = Path(Tuberculose)

if dir_tb_val.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(Tuberculose)

# %% [markdown]
# ### Ajuste de indice

# %%
# Define o image_id como o índice em df_data
df_data.set_index('image_id', inplace = True)

# %%
# Checamos df_data
df_data.head()
# Out:
#                         target  largura  altura  canais  maior_valor_pixel  \
# image_id
# CHNCXR_0454_1.png  Tuberculose     2896    2599       3                255
# CHNCXR_0212_0.png       Normal     2585    2792       3                255
# CHNCXR_0080_0.png       Normal     2955    3000       3                255
# CHNCXR_0433_1.png  Tuberculose     2942    3001       3                255
# CHNCXR_0132_0.png       Normal     2943    2997       3                255
#
#                    menor_valor_pixel  labels
# image_id
# CHNCXR_0454_1.png                  0       1
# CHNCXR_0212_0.png                  0       0
# CHNCXR_0080_0.png                  0       0
# CHNCXR_0433_1.png                  0       1
# CHNCXR_0132_0.png                  0       0

# %%
# Obtém uma lista de imagens em cada uma das duas pastas originais
folder_1 = os.listdir(imagens_shen)
folder_2 = os.listdir(imagens_mont)

# %%
folder_1[1:10]
# Out:
# ['CHNCXR_0002_0.png',
#  'CHNCXR_0003_0.png',
#  'CHNCXR_0004_0.png',
#  'CHNCXR_0005_0.png',
#  'CHNCXR_0006_0.png',
#  'CHNCXR_0007_0.png',
#  'CHNCXR_0008_0.png',
#  'CHNCXR_0009_0.png',
#  'CHNCXR_0010_0.png']

# %%
folder_2[1:10]
# Out:
# ['MCUCXR_0002_0.png',
#  'MCUCXR_0003_0.png',
#  'MCUCXR_0004_0.png',
#  'MCUCXR_0005_0.png',
#  'MCUCXR_0006_0.png',
#  'MCUCXR_0008_0.png',
#  'MCUCXR_0011_0.png',
#  'MCUCXR_0013_0.png',
#  'MCUCXR_0015_0.png']

# %%
lista_imagens_treino = list(df_treino['image_id'])
lista_imagens_val = list(df_val['image_id'])

# %%
lista_imagens_treino[20:30]
# Out:
# ['CHNCXR_0569_1.png',
#  'CHNCXR_0175_0.png',
#  'CHNCXR_0011_0.png',
#  'CHNCXR_0038_0.png',
#  'CHNCXR_0587_1.png',
#  'MCUCXR_0254_1.png',
#  'CHNCXR_0658_1.png',
#  'CHNCXR_0634_1.png',
#  'CHNCXR_0490_1.png',
#  'CHNCXR_0191_0.png']

# %%
lista_imagens_val[10:20]
# Out:
# ['CHNCXR_0562_1.png',
#  'CHNCXR_0230_0.png',
#  'CHNCXR_0492_1.png',
#  'CHNCXR_0323_0.png',
#  'CHNCXR_0440_1.png',
#  'CHNCXR_0196_0.png',
#  'CHNCXR_0500_1.png',
#  'CHNCXR_0154_0.png',
#  'CHNCXR_0622_1.png',
#  'CHNCXR_0420_1.png']

# %% [markdown]
# ## Pré-Processamento das Imagens

# %%
# Resize das imagens
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %%
print('\nPré-processamento dos dados de treino! Aguarde...')

# Loop pela lista de imagens de treino
for image in lista_imagens_treino:
    
    fname = image
    
    label = df_data.loc[image,'target']
    
    # Percorremos a folder_1 (imagens do dataset de shenzen) para buscar o caminho da imagem
    if fname in folder_1:
        
        src = os.path.join(imagens_shen, fname)
        
        dst = os.path.join(dados_treino, label, fname)
        
        image = cv2.imread(src)
        
        # Aplica o redimensionamento
        image = cv2.resize(image, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Salva a imagem no diretório de destino
        cv2.imwrite(dst, image)

    if fname in folder_2:
        
        src = os.path.join(imagens_mont, fname)
        
        dst = os.path.join(dados_treino, label, fname)
        
        image = cv2.imread(src)
        
        image = cv2.resize(image, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        cv2.imwrite(dst, image)

print('\nOs dados de treino estão prontos!')
# Out:
# Pré-processamento dos dados de treino! Aguarde...
#
# Os dados de treino estão prontos!

# %%
print('\nPré-processamento dos dados de valiação/teste! Aguarde...')

# Loop pela lista de imagens de validação/teste
for image in lista_imagens_val:
    
    fname = image
    
    label = df_data.loc[image,'target']
    
    # Percorremos a folder_1 (imagens do dataset de shenzen) para buscar o caminho da imagem
    if fname in folder_1:
        
        src = os.path.join(imagens_shen, fname)
        
        dst = os.path.join(dados_val, label, fname)
        
        image = cv2.imread(src)
        
        # Aplica o redimensionamento
        image = cv2.resize(image, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Salva a imagem no diretório de destino
        cv2.imwrite(dst, image)

    # Percorremos a folder_2 (imagens do dataset de montgomery) para buscar o caminho da imagem
    if fname in folder_2:
        
        src = os.path.join(imagens_mont, fname)
        
        dst = os.path.join(dados_val, label, fname)
        
        image = cv2.imread(src)
        
        image = cv2.resize(image, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        cv2.imwrite(dst, image)
        
print('\nOs dados de validação/teste estão prontos!')
# Out:
# Pré-processamento dos dados de valiação/teste! Aguarde...
#
# Os dados de validação/teste estão prontos!

# %%
# Verificamos quantas imagens de treino temos em cada pasta de classe
print(len(os.listdir(dados_treino + '/Normal')))
print(len(os.listdir(dados_treino + '/Tuberculose')))
# Out:
# 345
# 335

# %%
# Verificamos quantas imagens de validação temos em cada pasta de classe
print(len(os.listdir(dados_val + '/Normal')))
print(len(os.listdir(dados_val + '/Tuberculose')))
# Out:
# 61
# 59

# %% [markdown]
# ## Dataset Augmentaion (Geração de Imagens Sintéticas)
#
# Criaremos imagens sintéticas a partir das imagens existentes tipos de transformaçoes que serao feitas:
#
# - Rotação: Rotaciona as imagens aleatoriamente em até 10 graus para ambos os lados, aumentando a diversidade de orientações.
#
# - Deslocamento Horizontal: Desloca as imagens até 10% da largura para a esquerda ou para a direita, simulando variações horizontais.
#
# - Deslocamento Vertical: Desloca as imagens até 10% da altura para cima ou para baixo, simulando variações verticais.
#
# - Zoom: Aplica um zoom aleatório de até 10%, alterando o tamanho da imagem para representar diferentes distâncias.
#
# -  Espelhamento Horizontal: Inverte a imagem horizontalmente, criando uma versão espelhada para aumentar a diversidade.
#
# - Preenchimento: Preenche áreas vazias geradas pelas transformações com pixels próximos, utilizando o método de preenchimento nearest.

# %%
# Lista de classes
class_list = ['Normal', 'Tuberculose']

# %%
# Número de imagens sintéticas desejadas
NUM_IMAGENS_SINTETICAS = 2000

# %%
print('\nGeração de imagens sintéticas para treinamento! Aguarde...\n')

for item in class_list:
    
    aug_dir = base_dir + 'temp/'
    os.mkdir(aug_dir)
    
    img_dir = os.path.join(aug_dir, 'img_dir')
    os.mkdir(img_dir)

    img_class = item

    img_list = os.listdir(dados_treino + img_class)

    for fname in img_list:
            
            src = os.path.join(dados_treino + img_class, fname)
            
            dst = os.path.join(img_dir, fname)
            
            shutil.copyfile(src, dst)

    path = aug_dir
    save_path = dados_treino + img_class

    # Criamos um gerador de imagens 
    datagen = ImageDataGenerator(rotation_range = 10,
                                 width_shift_range = 0.1,
                                 height_shift_range = 0.1,
                                 zoom_range = 0.1,
                                 horizontal_flip = True,
                                 fill_mode = 'nearest')

    batch_size = 50

    aug_datagen = datagen.flow_from_directory(path,
                                              save_to_dir = save_path,
                                              save_format = 'png',
                                              target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
                                              batch_size = batch_size)
    
    
    num_files = len(os.listdir(img_dir))
    
    num_batches = int(np.ceil((NUM_IMAGENS_SINTETICAS - num_files) / batch_size))

    for i in range(0, num_batches):
        imgs, labels = next(aug_datagen)
        
    shutil.rmtree(aug_dir)
    
print('\nOs dados foram criados com sucesso!')
# Out:
# Geração de imagens sintéticas para treinamento! Aguarde...
#
# Found 345 images belonging to 1 classes.
# Found 335 images belonging to 1 classes.
#
# Os dados foram criados com sucesso!

# %% [markdown]
# ### Só utilizaremos as imagens sintéticas no dataset de treino

# %%
print(len(os.listdir(dados_treino + 'Normal')))
print(len(os.listdir(dados_treino + 'Tuberculose')))
# Out:
# 2025
# 1975

# %%
print(len(os.listdir(dados_val + 'Normal')))
print(len(os.listdir(dados_val + 'Tuberculose')))
# Out:
# 61
# 59

# %% [markdown]
# ### Visualiação de algumas imagens sintéticas

# %%
def plots(ims, figsize = (20,10), rows = 5, interp = False, titles = None): 
    
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    
    f = plt.figure(figsize = figsize)
    
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize = 16)
        plt.imshow(ims[i], interpolation = None if interp else 'none')

# %%
# Executa a função
plots(imgs, titles = labels)

# %% [markdown]
# ## Construção do Modelo

# %%
len(df_treino)
# Out:
# 680

# %%
len(df_val)
# Out:
# 120

# %%
# Número de exemplos de treinamento
num_amostras_treino = len(df_treino)

# Número de exemplos de validação
num_amostras_val = len(df_val)

# Tamanho do batch de treino
batch_size_treino = 10

# Tamanho do batch de validação
batch_size_val = 10

# %%
passos_treino = np.ceil(num_amostras_treino / batch_size_treino)
passos_val = np.ceil(num_amostras_val / batch_size_val)

# %% [markdown]
# ## Geração de batchs
# pelos motivos:
# - Eficiência Computacional: Processar dados em lotes reduz o número de atualizações de parâmetros, tornando o treinamento mais eficiente e aproveitando melhor o hardware (especialmente GPUs).
#
# - Estabilidade no Gradiente: Utilizar batches permite que o cálculo do gradiente seja baseado em múltiplos exemplos, reduzindo a variabilidade e tornando o processo de atualização mais estável e menos suscetível a ruídos.
#
# - Melhor Uso da Memória: Treinar em batches permite processar grandes conjuntos de dados em partes menores, facilitando o uso em sistemas com limitações de memória.

# %%
datagen = ImageDataGenerator(rescale = 1.0/255)

gen_treino = datagen.flow_from_directory(dados_treino,
                                         target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
                                         batch_size = batch_size_treino,
                                         class_mode = 'categorical')

gen_val = datagen.flow_from_directory(dados_val,
                                      target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
                                      batch_size = batch_size_val,
                                      class_mode = 'categorical')

gen_teste = datagen.flow_from_directory(dados_val,
                                        target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
                                        batch_size = batch_size_val,
                                        class_mode = 'categorical',
                                        shuffle = False)
# Out:
# Found 4000 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %% [markdown]
# Definimos os hiperparâmetros que serão usados para treinar o modelo. Esses valores podem ser modificados para ajustar o modelo e tentar obter melhor precisão.

# %%
# Tamanho do kernel
kernel_size = (3,3)

# Tamanho do Pool
pool_size = (2,2)

num_neurons_1 = 32

num_neurons_2 = 64

num_neurons_3 = 128

num_neurons_4 = 256

num_neurons_5 = 512

# Taxa de dropout nas camadas de convolução
dropout_conv = 0.3

# Taxa de dropout na camada densa
dropout_dense = 0.3

# Taxa de aprendizado
taxa_aprendizado = 0.00001

# Número de épocas de treinamento
num_epochs = 70

# %%
# Arquitetura do Modelo

model = Sequential()

# Adicionamos a primeira camada convolucional com 3 operações de convolução
model.add(Conv2D(num_neurons_1, kernel_size, activation = 'relu', input_shape = (IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
model.add(Conv2D(num_neurons_1, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_1, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size)) 
model.add(Dropout(dropout_conv))

# Adicionamos a segunda camada convolucional com 3 operações de convolução
model.add(Conv2D(num_neurons_2, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_2, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_2, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

# Adicionamos a terceira camada convolucional com 3 operações de convolução
model.add(Conv2D(num_neurons_3, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_3, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_3, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

# Adicionamos a quarta camada convolucional com 3 operações de convolução
model.add(Conv2D(num_neurons_4, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_4, kernel_size, activation = 'relu'))
model.add(Conv2D(num_neurons_4, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

# Camada de "achatamento"
model.add(Flatten())

# Camada densa com dropout
model.add(Dense(256, activation = "relu"))
model.add(Dropout(dropout_dense))

# Camada de saída
model.add(Dense(2, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 220, 220, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 218, 218, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 107, 107, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 105, 105, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 103, 103, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 51, 51, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 51, 51, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 49, 49, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 47, 47, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 45, 45, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 20, 20, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 18, 18, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,151,170 (23.46 MB)
#  Trainable params: 6,151,170 (23.46 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilação do modelo
model.compile(Adam(taxa_aprendizado), 
              loss = 'binary_crossentropy', 
              metrics = ['accuracy'])

# %%
modelos_base_dir = '.'
modelos_dir = os.path.join(modelos_base_dir, 'modelos/')

dir_modelos = Path(modelos_dir)

if dir_modelos.exists():
    print('O diretório já existe. Delete no SO e tente novamente.')
else:
    os.mkdir(modelos_dir)
# Out:
# O diretório já existe. Delete no SO e tente novamente.

# %%
modelo_salvo = modelos_dir + 'modelo_raiox.keras'

# %%
checkpoint = ModelCheckpoint(modelo_salvo, 
                             monitor = 'val_accuracy', 
                             verbose = 1, 
                             save_best_only = True, 
                             mode = 'max')

# %%
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', 
                              factor = 0.5, 
                              patience = 2, 
                              verbose = 1, 
                              mode = 'max',
                              min_lr = 0.0000001)

# %%
callbacks_list = [checkpoint, reduce_lr]

# %%
steps_per_epoch = int(passos_treino)
validation_steps = int(passos_val)
epochs = int(num_epochs)

# %% [markdown]
# ## Treinamento do Modelo

# %%
# %%time
history = model.fit(gen_treino,
                    steps_per_epoch=steps_per_epoch,
                    validation_data=gen_val,
                    validation_steps=validation_steps,
                    epochs=epochs,
                    verbose=1,
                    callbacks=callbacks_list
)
# Out:
# Epoch 1/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.4842 - loss: 0.6931
# Epoch 1: val_accuracy improved from -inf to 0.50833, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 19s 263ms/step - accuracy: 0.4846 - loss: 0.6931 - val_accuracy: 0.5083 - val_loss: 0.6930 - learning_rate: 1.0000e-05
# Epoch 2/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.5251 - loss: 0.6905 - learning_rate: 1.0000e-05
# Epoch 3/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.5323 - loss: 0.6904
# Epoch 3: val_accuracy did not improve from 0.50833
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.5323 - loss: 0.6903 - val_accuracy: 0.5083 - val_loss: 0.6926 - learning_rate: 1.0000e-05
# Epoch 4/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.5032 - loss: 0.6933 - learning_rate: 1.0000e-05
# Epoch 5/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4978 - loss: 0.6915
# Epoch 5: val_accuracy improved from 0.50833 to 0.55000, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.4979 - loss: 0.6915 - val_accuracy: 0.5500 - val_loss: 0.6921 - learning_rate: 1.0000e-05
# Epoch 6/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 15s 215ms/step - accuracy: 0.5572 - loss: 0.6889 - learning_rate: 1.0000e-05
# Epoch 7/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5240 - loss: 0.6851
# Epoch 7: val_accuracy improved from 0.55000 to 0.57500, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.5242 - loss: 0.6851 - val_accuracy: 0.5750 - val_loss: 0.6876 - learning_rate: 1.0000e-05
# Epoch 8/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - accuracy: 0.5970 - loss: 0.6779 - learning_rate: 1.0000e-05
# Epoch 9/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.6604 - loss: 0.6631
# Epoch 9: val_accuracy did not improve from 0.57500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.6602 - loss: 0.6630 - val_accuracy: 0.5667 - val_loss: 0.6660 - learning_rate: 1.0000e-05
# Epoch 10/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.6656 - loss: 0.6451 - learning_rate: 1.0000e-05
# Epoch 11/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.6045 - loss: 0.6559
# Epoch 11: val_accuracy improved from 0.57500 to 0.65000, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.6050 - loss: 0.6558 - val_accuracy: 0.6500 - val_loss: 0.6523 - learning_rate: 1.0000e-05
# Epoch 12/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 209ms/step - accuracy: 0.6784 - loss: 0.6217 - learning_rate: 1.0000e-05
# Epoch 13/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6424 - loss: 0.6370
# Epoch 13: val_accuracy improved from 0.65000 to 0.65833, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.6427 - loss: 0.6369 - val_accuracy: 0.6583 - val_loss: 0.6359 - learning_rate: 1.0000e-05
# Epoch 14/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.6570 - loss: 0.6243 - learning_rate: 1.0000e-05
# Epoch 15/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6539 - loss: 0.6192
# Epoch 15: val_accuracy did not improve from 0.65833
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6539 - loss: 0.6194 - val_accuracy: 0.5917 - val_loss: 0.6467 - learning_rate: 1.0000e-05
# Epoch 16/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 233ms/step - accuracy: 0.6746 - loss: 0.6292 - learning_rate: 1.0000e-05
# Epoch 17/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7146 - loss: 0.5912
# Epoch 17: val_accuracy improved from 0.65833 to 0.68333, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.7144 - loss: 0.5913 - val_accuracy: 0.6833 - val_loss: 0.6091 - learning_rate: 1.0000e-05
# Epoch 18/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 210ms/step - accuracy: 0.6819 - loss: 0.6149 - learning_rate: 1.0000e-05
# Epoch 19/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.6820 - loss: 0.6026
# Epoch 19: val_accuracy did not improve from 0.68333
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6819 - loss: 0.6027 - val_accuracy: 0.6333 - val_loss: 0.6224 - learning_rate: 1.0000e-05
# Epoch 20/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.6835 - loss: 0.6053 - learning_rate: 1.0000e-05
# Epoch 21/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.6290 - loss: 0.6643
# Epoch 21: val_accuracy improved from 0.68333 to 0.71667, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.6292 - loss: 0.6639 - val_accuracy: 0.7167 - val_loss: 0.6072 - learning_rate: 1.0000e-05
# Epoch 22/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 231ms/step - accuracy: 0.6756 - loss: 0.5949 - learning_rate: 1.0000e-05
# Epoch 23/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7009 - loss: 0.5894
# Epoch 23: val_accuracy did not improve from 0.71667
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.7006 - loss: 0.5896 - val_accuracy: 0.7083 - val_loss: 0.5872 - learning_rate: 1.0000e-05
# Epoch 24/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.7329 - loss: 0.5702 - learning_rate: 1.0000e-05
# Epoch 25/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7080 - loss: 0.5778
# Epoch 25: val_accuracy did not improve from 0.71667
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.7079 - loss: 0.5779 - val_accuracy: 0.7167 - val_loss: 0.5734 - learning_rate: 1.0000e-05
# Epoch 26/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 235ms/step - accuracy: 0.6911 - loss: 0.5937 - learning_rate: 5.0000e-06
# Epoch 27/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.6774 - loss: 0.6127
# Epoch 27: val_accuracy improved from 0.71667 to 0.72500, saving model to .\modelos/modelo_raiox.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 18s 263ms/step - accuracy: 0.6774 - loss: 0.6126 - val_accuracy: 0.7250 - val_loss: 0.5772 - learning_rate: 5.0000e-06
# Epoch 28/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - accuracy: 0.7209 - loss: 0.5600 - learning_rate: 5.0000e-06
# Epoch 29/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7118 - loss: 0.5880
# Epoch 29: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.7119 - loss: 0.5879 - val_accuracy: 0.7083 - val_loss: 0.5706 - learning_rate: 5.0000e-06
# Epoch 30/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 206ms/step - accuracy: 0.6593 - loss: 0.6037 - learning_rate: 5.0000e-06
# Epoch 31/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.6828 - loss: 0.5770
# Epoch 31: val_accuracy did not improve from 0.72500
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.6828 - loss: 0.5771 - val_accuracy: 0.7167 - val_loss: 0.5748 - learning_rate: 5.0000e-06
# Epoch 32/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.6354 - loss: 0.6061 - learning_rate: 2.5000e-06
# Epoch 33/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7086 - loss: 0.5909
# Epoch 33: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 18s 266ms/step - accuracy: 0.7088 - loss: 0.5904 - val_accuracy: 0.7167 - val_loss: 0.5664 - learning_rate: 2.5000e-06
# Epoch 34/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.6803 - loss: 0.5970 - learning_rate: 2.5000e-06
# Epoch 35/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.7121 - loss: 0.5776
# Epoch 35: val_accuracy did not improve from 0.72500
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.7123 - loss: 0.5773 - val_accuracy: 0.7000 - val_loss: 0.5654 - learning_rate: 2.5000e-06
# Epoch 36/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 15s 217ms/step - accuracy: 0.7515 - loss: 0.5539 - learning_rate: 1.2500e-06
# Epoch 37/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.7036 - loss: 0.5896
# Epoch 37: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.7035 - loss: 0.5896 - val_accuracy: 0.7167 - val_loss: 0.5587 - learning_rate: 1.2500e-06
# Epoch 38/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - accuracy: 0.7422 - loss: 0.5416 - learning_rate: 1.2500e-06
# Epoch 39/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.6929 - loss: 0.5941
# Epoch 39: val_accuracy did not improve from 0.72500
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6930 - loss: 0.5940 - val_accuracy: 0.7167 - val_loss: 0.5582 - learning_rate: 1.2500e-06
# Epoch 40/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.7199 - loss: 0.5395 - learning_rate: 6.2500e-07
# Epoch 41/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7040 - loss: 0.5460
# Epoch 41: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.7042 - loss: 0.5461 - val_accuracy: 0.7167 - val_loss: 0.5567 - learning_rate: 6.2500e-07
# Epoch 42/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 206ms/step - accuracy: 0.7268 - loss: 0.5634 - learning_rate: 6.2500e-07
# Epoch 43/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.7322 - loss: 0.5493
# Epoch 43: val_accuracy did not improve from 0.72500
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.7321 - loss: 0.5495 - val_accuracy: 0.7167 - val_loss: 0.5569 - learning_rate: 6.2500e-07
# Epoch 44/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.6681 - loss: 0.5856 - learning_rate: 3.1250e-07
# Epoch 45/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.6836 - loss: 0.5994
# Epoch 45: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 243ms/step - accuracy: 0.6836 - loss: 0.5994 - val_accuracy: 0.7083 - val_loss: 0.5607 - learning_rate: 3.1250e-07
# Epoch 46/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.7414 - loss: 0.5493 - learning_rate: 3.1250e-07
# Epoch 47/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7131 - loss: 0.5679
# Epoch 47: val_accuracy did not improve from 0.72500
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.7133 - loss: 0.5677 - val_accuracy: 0.7167 - val_loss: 0.5566 - learning_rate: 3.1250e-07
# Epoch 48/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 212ms/step - accuracy: 0.7039 - loss: 0.5659 - learning_rate: 1.5625e-07
# Epoch 49/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6779 - loss: 0.5918
# Epoch 49: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6783 - loss: 0.5916 - val_accuracy: 0.7250 - val_loss: 0.5570 - learning_rate: 1.5625e-07
# Epoch 50/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 233ms/step - accuracy: 0.7554 - loss: 0.5506 - learning_rate: 1.5625e-07
# Epoch 51/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.7283 - loss: 0.5667
# Epoch 51: val_accuracy did not improve from 0.72500
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-07.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.7282 - loss: 0.5666 - val_accuracy: 0.7167 - val_loss: 0.5575 - learning_rate: 1.5625e-07
# Epoch 52/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.7146 - loss: 0.5606 - learning_rate: 1.0000e-07
# Epoch 53/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7151 - loss: 0.5705
# Epoch 53: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.7149 - loss: 0.5706 - val_accuracy: 0.7167 - val_loss: 0.5577 - learning_rate: 1.0000e-07
# Epoch 54/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 206ms/step - accuracy: 0.7367 - loss: 0.5446 - learning_rate: 1.0000e-07
# Epoch 55/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7322 - loss: 0.5342
# Epoch 55: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.7320 - loss: 0.5345 - val_accuracy: 0.7167 - val_loss: 0.5566 - learning_rate: 1.0000e-07
# Epoch 56/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 232ms/step - accuracy: 0.7299 - loss: 0.5527 - learning_rate: 1.0000e-07
# Epoch 57/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.7546 - loss: 0.4926
# Epoch 57: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.7544 - loss: 0.4929 - val_accuracy: 0.7167 - val_loss: 0.5556 - learning_rate: 1.0000e-07
# Epoch 58/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.6759 - loss: 0.6005 - learning_rate: 1.0000e-07
# Epoch 59/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7156 - loss: 0.5490
# Epoch 59: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 243ms/step - accuracy: 0.7156 - loss: 0.5492 - val_accuracy: 0.7167 - val_loss: 0.5554 - learning_rate: 1.0000e-07
# Epoch 60/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.7378 - loss: 0.5391 - learning_rate: 1.0000e-07
# Epoch 61/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7417 - loss: 0.5615
# Epoch 61: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.7415 - loss: 0.5615 - val_accuracy: 0.7167 - val_loss: 0.5554 - learning_rate: 1.0000e-07
# Epoch 62/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.7276 - loss: 0.5567 - learning_rate: 1.0000e-07
# Epoch 63/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.6706 - loss: 0.6068
# Epoch 63: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.6709 - loss: 0.6065 - val_accuracy: 0.7083 - val_loss: 0.5542 - learning_rate: 1.0000e-07
# Epoch 64/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 235ms/step - accuracy: 0.6780 - loss: 0.5857 - learning_rate: 1.0000e-07
# Epoch 65/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7216 - loss: 0.5546
# Epoch 65: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.7212 - loss: 0.5548 - val_accuracy: 0.7083 - val_loss: 0.5537 - learning_rate: 1.0000e-07
# Epoch 66/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.7084 - loss: 0.5585 - learning_rate: 1.0000e-07
# Epoch 67/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7136 - loss: 0.5555
# Epoch 67: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.7138 - loss: 0.5555 - val_accuracy: 0.7083 - val_loss: 0.5543 - learning_rate: 1.0000e-07
# Epoch 68/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 232ms/step - accuracy: 0.7133 - loss: 0.5748 - learning_rate: 1.0000e-07
# Epoch 69/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7062 - loss: 0.5989
# Epoch 69: val_accuracy did not improve from 0.72500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.7064 - loss: 0.5987 - val_accuracy: 0.7083 - val_loss: 0.5539 - learning_rate: 1.0000e-07
# Epoch 70/70
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.7034 - loss: 0.5847 - learning_rate: 1.0000e-07
# CPU times: total: 2h 3min 32s
# Wall time: 19min 2s

# %%
# Obtém os nomes das métricas do modelo
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
# Carregamos o modelo treinado
model.load_weights('modelos/modelo_raiox.keras')

# %%
# Extraímos as métricas de treinamento
val_loss, val_acc = model.evaluate(gen_val, steps=validation_steps)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7348 - loss: 0.5791

# %%
# Imprimimos
print('\nErro do Modelo em Validação (val_loss):', val_loss)
print('Acurácia do Modelo em Validação (val_acc):', val_acc)
# Out:
# Erro do Modelo em Validação (val_loss): 0.5771647691726685
# Acurácia do Modelo em Validação (val_acc): 0.7250000238418579

# %% [markdown]
# Vamos visualizar a curva de aprendizado.

# %%
# Extrai as métricas
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# %%
# Plot

plt.plot(epochs, acc, '-', label = 'Acurácia em Treinamento', color = 'blue')
plt.title('Acurácia em Treinamento')
plt.legend()
plt.figure()

plt.plot(epochs, loss, '-', label = 'Erro em Treinamento', color = 'red')
plt.title('Erro em Treinamento')
plt.legend()
plt.figure()

# %%
epochs = range(1, len(val_acc) + 1)

plt.plot(epochs, val_acc, '-', label='Acurácia em Validação', color='green')
plt.title('Acurácia em Validação')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.show()

plt.plot(epochs, val_loss, '-', label='Erro em Validação', color='magenta')
plt.title('Erro em Validação')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Erro')
plt.show()

# %%
# Vamos obter os labels dos dados de teste
labels_teste = gen_teste.classes

# %%
# Precisamos dos labels para o plot da matriz de confusão
labels_teste.shape
# Out:
# (120,)

# %%
# Imprimimos a etiqueta (label) associada a cada classe
gen_teste.class_indices
# Out:
# {'Normal': 0, 'Tuberculose': 1}

# %%
# Fazemos as previsões
previsoes = model.predict(gen_teste, steps = validation_steps, verbose = 1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step

# %%
# Shape das previsões
previsoes.shape
# Out:
# (120, 2)

# %% [markdown]
# Vamos plotar uma Matriz de Confusão - Confusion Matrix.

# %%
# Função para a Matriz de Confusão
def plot_confusion_matrix(cm, 
                          classes,
                          normalize = False,
                          title = 'Matriz de Confusão',
                          cmap = plt.cm.YlOrRd):

    # Se normalize = True, obtemos a matriz de confusão com dados normalizados
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Matriz de Confusão Normalizada")
    else:
        print('Matriz de Confusão Sem Normalização')

    # Mostramos a Matriz de Confusão
    print(cm)

    # Plot
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    
    # Plot do texto
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), 
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")

    plt.ylabel('Label Verdadeiro')
    plt.xlabel('Label Previsto')
    plt.tight_layout()

# %%
matriz_conf = confusion_matrix(labels_teste, previsoes.argmax(axis = 1))

# %%
gen_teste.class_indices
# Out:
# {'Normal': 0, 'Tuberculose': 1}

# %%
matriz_conf_plot_labels = ['Normal', 'Tuberculose']

# %%
plot_confusion_matrix(matriz_conf, matriz_conf_plot_labels, title = 'Matriz de Confusão')
# Out:
# Matriz de Confusão Sem Normalização
# [[38 23]
#  [10 49]]

# %%
imagens_teste = gen_teste.filenames

# %%
imagens_teste
# Out:
# ['Normal\\CHNCXR_0006_0.png',
#  'Normal\\CHNCXR_0012_0.png',
#  'Normal\\CHNCXR_0019_0.png',
#  'Normal\\CHNCXR_0023_0.png',
#  'Normal\\CHNCXR_0025_0.png',
#  'Normal\\CHNCXR_0028_0.png',
#  'Normal\\CHNCXR_0030_0.png',
#  'Normal\\CHNCXR_0035_0.png',
#  'Normal\\CHNCXR_0037_0.png',
#  'Normal\\CHNCXR_0041_0.png',
#  'Normal\\CHNCXR_0042_0.png',
#  'Normal\\CHNCXR_0047_0.png',
#  'Normal\\CHNCXR_0048_0.png',
#  'Normal\\CHNCXR_0057_0.png',
#  'Normal\\CHNCXR_0061_0.png',
#  'Normal\\CHNCXR_0073_0.png',
#  'Normal\\CHNCXR_0081_0.png',
#  'Normal\\CHNCXR_0082_0.png',
#  'Normal\\CHNCXR_0086_0.png',
#  'Normal\\CHNCXR_0110_0.png',
#  'Normal\\CHNCXR_0114_0.png',
#  'Normal\\CHNCXR_0118_0.png',
#  'Normal\\CHNCXR_0122_0.png',
#  'Normal\\CHNCXR_0139_0.png',
#  'Normal\\CHNCXR_0154_0.png',
#  'Normal\\CHNCXR_0165_0.png',
#  'Normal\\CHNCXR_0166_0.png',
#  'Normal\\CHNCXR_0176_0.png',
#  'Normal\\CHNCXR_0177_0.png',
#  'Normal\\CHNCXR_0179_0.png',
#  'Normal\\CHNCXR_0181_0.png',
#  'Normal\\CHNCXR_0182_0.png',
#  'Normal\\CHNCXR_0196_0.png',
#  'Normal\\CHNCXR_0200_0.png',
#  'Normal\\CHNCXR_0204_0.png',
#  'Normal\\CHNCXR_0207_0.png',
#  'Normal\\CHNCXR_0210_0.png',
#  'Normal\\CHNCXR_0212_0.png',
#  'Normal\\CHNCXR_0214_0.png',
#  'Normal\\CHNCXR_0222_0.png',
#  'Normal\\CHNCXR_0223_0.png',
#  'Normal\\CHNCXR_0227_0.png',
#  'Normal\\CHNCXR_0230_0.png',
#  'Normal\\CHNCXR_0231_0.png',
#  'Normal\\CHNCXR_0256_0.png',
#  'Normal\\CHNCXR_0277_0.png',
#  'Normal\\CHNCXR_0278_0.png',
#  'Normal\\CHNCXR_0285_0.png',
#  'Normal\\CHNCXR_0301_0.png',
#  'Normal\\CHNCXR_0306_0.png',
#  'Normal\\CHNCXR_0323_0.png',
#  'Normal\\MCUCXR_0029_0.png',
#  'Normal\\MCUCXR_0041_0.png',
#  'Normal\\MCUCXR_0042_0.png',
#  'Normal\\MCUCXR_0045_0.png',
#  'Normal\\MCUCXR_0059_0.png',
#  'Normal\\MCUCXR_0083_0.png',
#  'Normal\\MCUCXR_0085_0.png',
#  'Normal\\MCUCXR_0092_0.png',
#  'Normal\\MCUCXR_0095_0.png',
#  'Normal\\MCUCXR_0096_0.png',
#  'Tuberculose\\CHNCXR_0335_1.png',
#  'Tuberculose\\CHNCXR_0339_1.png',
#  'Tuberculose\\CHNCXR_0343_1.png',
#  'Tuberculose\\CHNCXR_0354_1.png',
#  'Tuberculose\\CHNCXR_0357_1.png',
#  'Tuberculose\\CHNCXR_0358_1.png',
#  'Tuberculose\\CHNCXR_0363_1.png',
#  'Tuberculose\\CHNCXR_0369_1.png',
#  'Tuberculose\\CHNCXR_0383_1.png',
#  'Tuberculose\\CHNCXR_0384_1.png',
#  'Tuberculose\\CHNCXR_0385_1.png',
#  'Tuberculose\\CHNCXR_0388_1.png',
#  'Tuberculose\\CHNCXR_0393_1.png',
#  'Tuberculose\\CHNCXR_0398_1.png',
#  'Tuberculose\\CHNCXR_0401_1.png',
#  'Tuberculose\\CHNCXR_0402_1.png',
#  'Tuberculose\\CHNCXR_0410_1.png',
#  'Tuberculose\\CHNCXR_0414_1.png',
#  'Tuberculose\\CHNCXR_0419_1.png',
#  'Tuberculose\\CHNCXR_0420_1.png',
#  'Tuberculose\\CHNCXR_0424_1.png',
#  'Tuberculose\\CHNCXR_0425_1.png',
#  'Tuberculose\\CHNCXR_0432_1.png',
#  'Tuberculose\\CHNCXR_0438_1.png',
#  'Tuberculose\\CHNCXR_0440_1.png',
#  'Tuberculose\\CHNCXR_0441_1.png',
#  'Tuberculose\\CHNCXR_0463_1.png',
#  'Tuberculose\\CHNCXR_0469_1.png',
#  'Tuberculose\\CHNCXR_0475_1.png',
#  'Tuberculose\\CHNCXR_0476_1.png',
#  'Tuberculose\\CHNCXR_0487_1.png',
#  'Tuberculose\\CHNCXR_0492_1.png',
#  'Tuberculose\\CHNCXR_0498_1.png',
#  'Tuberculose\\CHNCXR_0500_1.png',
#  'Tuberculose\\CHNCXR_0510_1.png',
#  'Tuberculose\\CHNCXR_0521_1.png',
#  'Tuberculose\\CHNCXR_0522_1.png',
#  'Tuberculose\\CHNCXR_0526_1.png',
#  'Tuberculose\\CHNCXR_0530_1.png',
#  'Tuberculose\\CHNCXR_0535_1.png',
#  'Tuberculose\\CHNCXR_0538_1.png',
#  'Tuberculose\\CHNCXR_0539_1.png',
#  'Tuberculose\\CHNCXR_0543_1.png',
#  'Tuberculose\\CHNCXR_0562_1.png',
#  'Tuberculose\\CHNCXR_0571_1.png',
#  'Tuberculose\\CHNCXR_0572_1.png',
#  'Tuberculose\\CHNCXR_0598_1.png',
#  'Tuberculose\\CHNCXR_0604_1.png',
#  'Tuberculose\\CHNCXR_0616_1.png',
#  'Tuberculose\\CHNCXR_0622_1.png',
#  'Tuberculose\\CHNCXR_0625_1.png',
#  'Tuberculose\\CHNCXR_0633_1.png',
#  'Tuberculose\\CHNCXR_0635_1.png',
#  'Tuberculose\\MCUCXR_0140_1.png',
#  'Tuberculose\\MCUCXR_0170_1.png',
#  'Tuberculose\\MCUCXR_0282_1.png',
#  'Tuberculose\\MCUCXR_0338_1.png',
#  'Tuberculose\\MCUCXR_0367_1.png',
#  'Tuberculose\\MCUCXR_0399_1.png']

# %%
y_true = gen_teste.classes

# %%
y_pred = previsoes.argmax(axis=1)

# %% [markdown]
# Relatório de Classificação

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_true, y_pred, target_names = matriz_conf_plot_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.79      0.62      0.70        61
#  Tuberculose       0.68      0.83      0.75        59
#
#     accuracy                           0.72       120
#    macro avg       0.74      0.73      0.72       120
# weighted avg       0.74      0.72      0.72       120

# %% [markdown]
# - Recall = Dada uma classe, o classificador será capaz de detectá-la?
#
# - Precision = Dada uma previsão de classe, qual a probabilidade de estar correta?
#
# - F1 Score = A média harmônica de Recall e Precision. Essencialmente, ele pune valores extremos.

# %% [markdown]
# # Fim
